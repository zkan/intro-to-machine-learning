# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
mean = [0, 0]
cov = [[1, 0], 
       [10, 10]]
X = np.random.multivariate_normal(mean, cov, 100)
plt.plot(X[:, 0], X[:, 1], 'o', alpha=0.5)
plt.axis('equal')
# Out:
# /Users/zkan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   after removing the cwd from sys.path.
# (-6.021513694717299, 7.205150965082573, -7.574460981521951, 6.68554513157919)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X)
print(pca.explained_variance_)
print(pca.components_)
# Out:
# [12.5469334   0.91779965]
# [[-0.70120218 -0.71296248]
#  [ 0.71296248 -0.70120218]]

# %%
plt.plot(X[:, 0], X[:, 1], 'o', alpha=0.5)
for length, vector in zip(pca.explained_variance_, pca.components_):
    v = vector * 3 * np.sqrt(length)
    plt.plot([0, v[0]], [0, v[1]], '-k', linewidth=3)
plt.axis('equal');

# %%
pca = PCA(0.95)
X_trans = pca.fit_transform(X)
print(X.shape)
print(X_trans.shape)
print(pca.explained_variance_)
print(pca.components_)
# Out:
# (100, 2)
# (100, 2)
# [12.5469334   0.91779965]
# [[-0.70120218 -0.71296248]
#  [ 0.71296248 -0.70120218]]

# %%
pca = PCA(n_components=1)
X_trans = pca.fit_transform(X)
print(X.shape)
print(X_trans.shape)
print(pca.explained_variance_)
print(pca.components_)
# Out:
# (100, 2)
# (100, 1)
# [12.5469334]
# [[-0.70120218 -0.71296248]]

# %%
X_new = pca.inverse_transform(X_trans)
plt.plot(X[:, 0], X[:, 1], 'o', alpha=0.2)
plt.plot(X_new[:, 0], X_new[:, 1], 'bo', alpha=0.8)
plt.axis('equal');
